# %%
# %matplotlib widget
import numpy as np
import scipy
import obspy
from obspy.signal.cross_correlation import correlate, xcorr_max
from obspy.clients.fdsn.mass_downloader import RectangularDomain, Restrictions, MassDownloader
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.widgets import Button
import matplotlib.patches as mpatches
import matplotlib.dates as mdates
from matplotlib.colors import LogNorm
from matplotlib.ticker import LogFormatterMathtext
from scipy.signal import spectrogram
import datetime
from geopy.distance import distance
import glob
import time
import os

# %%
'''

Download data

'''

domain = RectangularDomain(minlatitude=-90, maxlatitude=90, minlongitude=-180, maxlongitude=180.0)

restrictions = Restrictions(
    starttime=obspy.UTCDateTime(2010, 1, 1),
    endtime=obspy.UTCDateTime(2022, 1, 1),
    chunklength_in_sec=86400,
    network="YT", station="MA01,MA02,MA08,MCRG", location="", channel="HH*",
    location_priorities = ["01",],
    channel_priorities = ["HHZ","HHN","HHE"],
    reject_channels_with_gaps=False,
    minimum_length=0.0)

mseed_storage=("/media/Data/Data/YT/MSEED/raw/")

mdl = MassDownloader(providers=["IRIS"])

mdl.download(
    domain=domain,
    restrictions=restrictions, 
    mseed_storage=mseed_storage, 
    stationxml_storage=("/media/Data/Data/YT/XML/"))
# Out:
# [2022-03-01 09:58:11,462] - obspy.clients.fdsn.mass_downloader - INFO: Initializing FDSN client(s) for IRIS.
# [2022-03-01 09:58:11,467] - obspy.clients.fdsn.mass_downloader - INFO: Successfully initialized 1 client(s): IRIS.
# [2022-03-01 09:58:11,468] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2022-03-01 09:58:11,469] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Requesting reliable availability.
# [2022-03-01 09:58:11,531] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully requested availability (0.06 seconds)
# [2022-03-01 09:58:14,548] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Found 4 stations (12 channels).
# [2022-03-01 09:58:15,116] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Will attempt to download data from 4 stations.
# [2022-03-01 09:58:17,212] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Status for 7614 time intervals/channels before downloading: EXISTS
# [2022-03-01 09:58:17,213] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Status for 44982 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2022-03-01 09:58:17,445] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:17,527] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:17,531] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:17,742] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:17,751] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:17,844] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:17,950] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:17,960] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:18,156] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:18,159] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:18,168] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:18,365] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:18,376] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:18,461] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:18,577] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:18,604] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:18,786] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:18,845] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:18,897] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:18,995] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:19,155] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:19,203] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:19,206] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:19,364] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:19,414] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:19,523] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:19,573] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:19,624] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:19,782] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:19,822] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:19,833] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:19,991] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:20,041] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:20,135] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:20,200] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:20,249] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:20,409] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:20,437] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:20,459] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:20,646] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:20,670] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:20,670] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:20,856] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:20,966] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:21,009] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:21,066] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:21,263] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:21,275] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:21,319] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:21,485] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:21,620] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:21,628] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:21,701] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:21,914] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:21,926] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:21,929] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:22,124] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:22,233] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:22,243] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:22,332] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:22,530] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:22,541] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:22,544] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:22,751] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:22,842] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:22,893] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:22,960] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:23,052] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:23,170] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:23,194] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:23,262] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:23,378] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:23,404] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:23,472] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:23,588] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:23,682] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:23,703] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:23,797] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:23,891] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:24,036] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:24,100] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:24,144] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:24,245] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:24,359] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:24,450] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:24,456] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:24,658] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:24,679] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:24,756] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:25,012] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:25,034] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:25,079] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:25,243] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:25,338] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:25,374] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:25,452] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:25,638] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:25,661] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:25,678] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:25,873] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:25,951] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:25,995] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:26,082] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:26,250] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:26,313] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:26,381] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:26,564] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:26,662] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:26,732] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:26,881] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:26,941] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:26,969] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:27,151] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:27,178] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:27,241] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:27,386] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:27,422] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:27,593] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:27,596] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:27,725] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:27,802] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:27,805] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:27,934] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:28,011] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:28,015] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:28,196] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:28,234] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:28,275] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:28,405] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:28,443] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:28,485] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:28,652] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:28,799] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:28,955] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:29,009] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:29,165] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:29,218] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:29,401] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:29,427] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:29,737] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:29,743] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:30,043] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:30,261] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:30,364] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:30,626] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:30,835] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:30,989] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:31,046] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:31,106] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:31,350] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:31,361] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:31,417] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:31,736] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:31,752] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:31,774] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:31,946] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:32,120] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:32,155] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:32,210] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:32,415] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:32,535] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:32,542] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:32,625] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:32,835] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:32,842] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:32,906] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:33,045] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:33,148] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:33,214] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:33,256] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:33,357] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:33,464] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:33,525] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:33,566] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:33,681] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:33,774] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:33,906] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:33,942] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:33,984] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:34,193] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:34,233] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:34,328] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:34,402] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:34,542] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:34,612] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:34,680] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:34,858] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:34,973] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:34,994] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:35,186] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:35,232] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:35,307] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:35,502] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:35,516] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:35,562] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:35,726] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:35,825] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:35,918] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:35,935] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:36,122] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:36,145] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:36,246] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:36,354] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:36,436] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:36,563] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:36,573] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:36,772] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:36,800] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:36,893] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:36,981] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:37,166] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:37,191] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:37,246] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:37,400] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:37,482] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:37,543] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:37,608] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:37,802] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:37,803] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:37,816] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:38,025] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:38,100] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:38,107] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:38,233] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:38,415] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:38,418] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:38,443] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:38,626] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:38,651] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:38,676] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:38,842] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:38,860] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:38,977] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:39,058] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:39,067] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:39,267] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:39,275] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:39,343] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:39,484] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:39,525] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:39,692] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:39,709] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:39,734] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:39,944] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:40,004] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:40,122] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:40,152] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:40,212] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:40,361] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:40,415] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:40,420] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:40,631] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:40,716] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:40,787] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:40,940] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:40,999] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:41,026] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:41,199] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:41,207] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:41,328] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:41,411] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:41,415] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:41,621] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:41,625] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:41,654] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:41,833] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:41,862] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:41,987] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:42,044] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:42,182] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:42,391] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:42,401] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:42,426] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:42,600] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:42,709] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:42,793] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:42,808] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:43,011] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:43,016] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:43,164] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:43,273] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:43,324] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:43,374] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:43,482] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:43,534] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:43,590] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:43,689] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:43,840] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:43,899] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:43,993] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:44,153] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:44,214] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:44,253] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:44,477] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:44,513] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:44,534] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:44,721] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:44,797] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:44,844] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:44,981] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:45,120] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:45,165] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:45,200] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:45,410] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:45,489] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:45,523] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:45,706] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:45,795] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:45,882] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:46,020] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:46,169] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:46,202] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:46,324] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:46,474] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:46,503] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:46,626] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:46,786] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:46,825] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:46,933] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:47,085] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:47,147] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:47,228] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:47,294] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:47,436] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:47,459] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:47,597] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:47,645] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:47,779] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:47,855] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:47,901] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:48,063] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:48,091] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:48,198] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:48,372] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:48,406] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:48,525] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:48,681] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:48,726] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:48,840] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:49,044] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:49,095] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:49,149] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:49,352] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:49,414] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:49,479] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:49,561] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:49,723] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:49,770] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:49,837] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:49,979] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:50,043] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:50,141] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:50,291] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:50,339] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:50,400] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:50,613] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:50,623] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:50,663] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:50,823] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:50,873] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:50,941] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:51,032] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:51,172] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:51,242] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:51,261] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:51,470] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:51,568] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:51,608] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:51,791] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:51,884] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:51,925] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:52,001] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:52,206] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:52,235] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:52,311] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:52,444] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:52,523] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:52,632] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:52,653] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:52,732] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:52,863] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:52,997] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:53,032] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:53,072] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:53,290] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:53,306] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:53,342] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:53,501] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:53,517] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:53,655] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:53,711] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:53,725] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:53,920] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:53,934] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:53,976] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 09:58:54,129] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# ...
# [2022-03-01 10:19:27,021] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:27,119] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:27,215] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:27,266] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:27,367] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:27,462] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:27,514] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:27,611] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:27,709] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:27,760] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:27,857] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:27,955] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:28,007] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:28,102] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:28,255] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:28,348] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:28,468] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:28,501] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:28,596] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:28,715] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:28,748] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:28,843] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:28,963] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:29,210] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:29,246] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:29,248] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:29,456] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:29,494] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:29,494] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:29,702] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:29,740] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:29,743] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:29,949] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:29,986] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:29,991] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:30,198] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:30,233] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:30,235] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:30,445] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:30,482] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:30,485] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:30,692] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:30,733] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:30,733] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:30,939] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:30,983] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:30,985] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:31,187] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:31,231] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:31,234] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:31,431] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:31,476] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:31,481] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:31,678] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:31,724] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:31,726] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:31,925] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:31,971] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:31,974] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:32,173] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:32,217] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:32,221] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:32,421] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:32,462] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:32,469] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:32,709] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:32,715] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:32,794] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:32,956] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:33,040] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:33,178] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:33,203] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:33,287] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:33,427] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:33,534] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:33,578] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:33,676] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:33,783] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:33,923] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:33,978] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:34,028] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:34,170] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:34,275] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:34,279] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:34,417] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:34,520] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:34,664] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:34,768] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:34,800] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:34,912] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:35,013] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:35,156] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:35,260] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:35,403] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:35,406] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:35,583] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:35,662] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:35,830] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:35,908] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:35,910] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:36,077] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:36,156] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:36,321] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:36,400] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:36,411] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:36,570] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:36,787] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:36,818] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:36,915] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:37,064] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:37,188] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:37,320] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:37,492] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:37,517] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:37,567] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:37,814] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:37,889] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:38,059] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:38,125] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:38,192] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:38,306] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:38,553] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:38,594] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:38,799] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:38,826] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:38,896] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:39,046] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:39,292] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:39,294] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:39,528] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:39,540] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:39,542] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:39,775] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:39,790] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-03-01 10:19:40,023] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.

# %%
'''

Set station and channel info

'''

path = "/media/Data/Data/"
networks = ["YT"]
stats = [["MCRG","MA01","MA02","MA08"]]
chans = ["HH*"]

# %%
'''

Remove instrumental response

'''

# set times of interest
time_win_dict = {}
time_win_dict[0] = {'start':datetime.datetime(2011,10,2),'end':datetime.datetime(2011,10,10)}
time_win_dict[1] = {'start':datetime.datetime(2012,5,8),'end':datetime.datetime(2012,5,10)}
time_win_dict[2] = {'start':datetime.datetime(2015,7,8),'end':datetime.datetime(2015,7,20)}
time_win_dict[3] = {'start':datetime.datetime(2017,9,13),'end':datetime.datetime(2017,9,25)}
time_win_dict[4] = {'start':datetime.datetime(2018,9,21),'end':datetime.datetime(2018,10,25)}

#set frequency band for response removal
prefilt = [[0.0005,0.001,45,50]]

for i in range(len(time_win_dict)):
    for n in range(len(networks)):
        duration = time_win_dict[i]['end']-time_win_dict[i]['start']
        files = []
        for day in range(0,duration.days):
            date = time_win_dict[i]['start']+datetime.timedelta(days=day)
            files.extend([path + networks[n] + "/MSEED/raw/" + stat + "/*" + chans[n] + "__" + str(date.year) + date.strftime('%m') + date.strftime('%d') + "T000000Z__" + "*" for stat in stats[n]])

        #loop through all raw files
        for f in files:

            #start timer
            t = time.time()

            #read in one data file
            try:
                st = obspy.read(f)
            except:
                print("No data for " + str(f))
                continue
                
            #grab a couple useful variables from file metadata
            station = st[0].stats.station
            channel = st[0].stats.channel
            start_date = str(st[0].stats.starttime).split("T")[0]

            #specify output filename format
            out_path = "data/MSEED/"+networks[n]+"/"
            out_file = out_path + st[0].stats.station + "_" + start_date + "_" + str(prefilt[n][1]) + "-" + str(prefilt[n][2]) + "Hz.MSEED"
            if not os.path.exists(out_path):
                os.makedirs(out_path)

            #preprocess file
            st.detrend("demean")
            st.detrend("linear")
            st.taper(max_percentage=0.00025, max_length=20.)

            #read correct stationXML file
            XML_path = glob.glob(path + networks[n] + "/XML/*" + station + "*.xml")[0]
            inv = obspy.read_inventory(XML_path)

            #remove instrument response
            st.remove_response(inventory=inv,pre_filt=prefilt[n],output="VEL")

            #write new file
            st.write(out_file,format='MSEED')

            #end timer
            run_time = time.time() - t

            #give some output to check progress
            print("Response removed from " + f + " in " + str(run_time) + " seconds.")

# %%
'''

Check which stations are available for times where imagery suggests rift activity

'''

# set times of interest
time_win_dict = {}
time_win_dict[0] = {'start':datetime.datetime(2011,10,2),'end':datetime.datetime(2011,10,10)}
time_win_dict[1] = {'start':datetime.datetime(2015,7,8),'end':datetime.datetime(2015,7,20)}
time_win_dict[2] = {'start':datetime.datetime(2017,9,13),'end':datetime.datetime(2017,9,25)}
time_win_dict[3] = {'start':datetime.datetime(2018,9,21),'end':datetime.datetime(2018,10,25)}

# plot station availability during times of interest
fig = plt.figure(figsize=(15,5))
position = 0
for n in range(len(networks)):
    for s in range(len(stats[n])):
        files = glob.glob(path + networks[n] + "/MSEED/raw/" + stats[n][s] + "/*" + chans[n] + "*")
        dates = [datetime.datetime.strptime(f.split("__")[1],"%Y%m%dT000000Z") for f in files]
        plt.plot(dates,np.ones(len(dates))+position,label=stats[n][s])
        position += 1
plt.legend()
plt.title("Station availability")
plt.show()

rifts = ["2011 rift","2015 rift","2017 rift", "2018 rift"]
fig,ax = plt.subplots(len(time_win_dict),figsize=(10,12))
position = 0
for i in range(len(time_win_dict)):
    for n in range(len(networks[n])):
        for s in range(len(stats[n])):
            files = glob.glob(path + networks[n] + "/MSEED/raw/" + stats[n][s] + "/*" + chans[n] + "*")
            dates = np.array([datetime.datetime.strptime(f.split("__")[1],"%Y%m%dT000000Z") for f in files])
            time_ind = np.logical_and([dates>time_win_dict[i]['start']],[dates<time_win_dict[i]['end']])[0]
            ax[i].plot(dates[time_ind],np.ones(len(dates[time_ind]))+position,label=stats[n][s])
            position+=1
    ax[i].set_title(rifts[i])
    ax[i].legend()
plt.tight_layout()

# %%
'''

Plot all available data for each time period of interest

'''

# set times of interest
time_win_dict = {}
#time_win_dict[0] = {'start':datetime.datetime(2011,10,2),'end':datetime.datetime(2011,10,10)}
#time_win_dict[1] = {'start':datetime.datetime(2012,5,8),'end':datetime.datetime(2012,5,10)}
#time_win_dict[2] = {'start':datetime.datetime(2015,7,8),'end':datetime.datetime(2015,7,20)}
#time_win_dict[3] = {'start':datetime.datetime(2017,9,13),'end':datetime.datetime(2017,9,25)}
#time_win_dict[4] = {'start':datetime.datetime(2018,9,21),'end':datetime.datetime(2018,10,25)}

time_win_dict[0] = {'start':datetime.datetime(2017,9,13),'end':datetime.datetime(2017,9,14)}

# choose channel and frequency band
chan = "*Z"
low_cut = 1
high_cut = 5

# make labels for plots
#rifts = ["2011 rift","2015 rift","2017 rift", "2018 rift"]
rifts = ["2017 rift"]

for i in range(len(time_win_dict)):
    data_dict = {}
    # read all data available on the current day
    duration = time_win_dict[i]['end']-time_win_dict[i]['start']
    for day in range(0,duration.days):

        # get date from time window dictionary
        date = time_win_dict[i]['start']+datetime.timedelta(days=day)

        # read and preprocess data
        st = obspy.read("data/MSEED/*/*" + str(date.year) + "-" + date.strftime('%m') + "-" + date.strftime('%d') + "*")
        st.detrend("demean")
        st.detrend("linear")
        st.taper(max_percentage=0.00025, max_length=20.)
        st.filter("bandpass",freqmin=low_cut,freqmax=high_cut)
        st.resample(high_cut*2)
        
        for tr in st.select(channel=chan):
            data_key = tr.stats.station+tr.stats.channel+"_data"
            time_key = tr.stats.station+tr.stats.channel+"_time"
            if data_key in data_dict.keys():
                data_dict[data_key] = np.append(data_dict[data_key],tr.data)
                data_dict[time_key] = np.append(data_dict[time_key],tr.times(type="matplotlib"))
            else:
                data_dict[data_key] = tr.data
                data_dict[time_key] = tr.times(type="matplotlib")

    fig,ax = plt.subplots(len(data_dict)//2,1,figsize=(20,10))
    data_keys = [k for k in data_dict.keys() if "data" in k]
    time_keys = [k for k in data_dict.keys() if "time" in k]
    nrows = len(data_keys)-1
    for k in range(len(data_keys)):
        ax[k].plot(data_dict[time_keys[k]],data_dict[data_keys[k]],color='k')
        ax[k].get_xaxis().set_ticklabels([])
        ax[nrows].get_shared_x_axes().join(ax[nrows],ax[k])
        ax[k].set_ylabel("Velocity (m/s)")
        ax[k].set_title(data_keys[k].split("_")[0])
        if k == nrows:
            ax[k].xaxis.set_major_formatter(mdates.DateFormatter('%m/%d\n%H:%M'))
    plt.suptitle("Data surrounding " + rifts[i] + " extension (" + str(low_cut)+"-" + str(high_cut)+" Hz)")
    plt.tight_layout()
    plt.savefig("outputs/timeseries/" + time_win_dict[i]['start'].strftime("%Y-%m-%d") + "_" + time_win_dict[i]['end'].strftime("%Y-%m-%d") + "_" + chan.split("*")[1] + "_" + str(low_cut)+ "-" + str(high_cut)+ "Hz" + ".png")

# %%
'''

Investigate likely event time windows based on backprojection images

'''

windows = [datetime.datetime(2017,9,13,2,40),
          datetime.datetime(2017,9,13,6),
          datetime.datetime(2017,9,13,6,20),
          datetime.datetime(2017,9,13,8,15),
          datetime.datetime(2017,9,13,11,5),
          datetime.datetime(2017,9,13,14,5),
          datetime.datetime(2017,9,13,15,25),
          datetime.datetime(2017,9,13,16),
          datetime.datetime(2017,9,13,17,20),
          datetime.datetime(2017,9,13,18),
          datetime.datetime(2017,9,13,18,50),
          datetime.datetime(2017,9,13,23)]

for i in range(len(ax)):
    ax[i].set_xlim([windows[0]-datetime.timedelta(seconds=600),windows[0]+datetime.timedelta(seconds=600)])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
