# %%
# %matplotlib widget
import numpy as np
import scipy
import obspy
from obspy.signal.cross_correlation import correlate, xcorr_max
from obspy.clients.fdsn.mass_downloader import RectangularDomain, Restrictions, MassDownloader
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.widgets import Button
import matplotlib.patches as mpatches
import matplotlib.dates as mdates
from matplotlib.colors import LogNorm
from matplotlib.ticker import LogFormatterMathtext
from scipy.signal import spectrogram
import datetime
from geopy.distance import distance
import glob
import time
import os

# %%
'''

Download data

'''

domain = RectangularDomain(minlatitude=-90, maxlatitude=90, minlongitude=-180, maxlongitude=180.0)

restrictions = Restrictions(
    starttime=obspy.UTCDateTime(2010, 1, 1),
    endtime=obspy.UTCDateTime(2022, 1, 1),
    chunklength_in_sec=86400,
    network="YT", station="MA01,MA02,MA08,MCRG", location="", channel="HH*",
    location_priorities = ["01",],
    channel_priorities = ["HHZ","HHN","HHE"],
    reject_channels_with_gaps=False,
    minimum_length=0.0)

mseed_storage=("/media/Data/Data/YT/MSEED/raw/")

mdl = MassDownloader(providers=["IRIS"])

mdl.download(
    domain=domain,
    restrictions=restrictions, 
    mseed_storage=mseed_storage, 
    stationxml_storage=("/media/Data/Data/YT/XML/"))
# Out:
# [2022-02-28 11:15:33,387] - obspy.clients.fdsn.mass_downloader - INFO: Initializing FDSN client(s) for IRIS.
# [2022-02-28 11:15:33,393] - obspy.clients.fdsn.mass_downloader - INFO: Successfully initialized 1 client(s): IRIS.
# [2022-02-28 11:15:33,394] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2022-02-28 11:15:33,395] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Requesting reliable availability.
# [2022-02-28 11:15:33,408] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully requested availability (0.01 seconds)
# [2022-02-28 11:15:36,078] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Found 4 stations (12 channels).
# [2022-02-28 11:15:36,539] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Will attempt to download data from 4 stations.
# [2022-02-28 11:15:38,499] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Status for 52596 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2022-02-28 11:15:38,726] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:38,915] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:38,916] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:38,938] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:39,125] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:39,130] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:39,202] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:39,333] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:39,426] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:39,432] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:39,543] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:39,732] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:39,753] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:39,767] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:40,064] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:40,072] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:40,079] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:40,376] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:40,379] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:40,410] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:40,590] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:40,691] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:40,720] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:40,800] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:40,999] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:41,032] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:41,111] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:41,242] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:41,305] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:41,371] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:41,451] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:41,517] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:41,579] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:41,780] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:41,822] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:41,884] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:42,077] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:42,140] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:42,195] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:42,373] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:42,445] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:42,493] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:42,689] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:42,754] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:42,817] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:42,963] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:42,999] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:43,140] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:43,172] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:43,314] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:43,381] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:43,443] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:43,523] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:43,591] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:43,673] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:43,732] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:43,800] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:43,887] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:44,012] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:44,031] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:44,207] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:44,331] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:44,343] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:44,510] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:44,552] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:44,644] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:44,823] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:44,851] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:44,959] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:45,153] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:45,167] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:45,317] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:45,412] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:45,479] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:45,623] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:45,631] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:45,777] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:45,841] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:45,882] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:46,049] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:46,075] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:46,095] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:46,378] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:46,407] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:46,409] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:46,669] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:46,723] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:46,725] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:46,878] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:46,934] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:47,021] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:47,137] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:47,229] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:47,329] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:47,346] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:47,527] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:47,539] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:47,556] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:47,738] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:47,747] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:47,764] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:47,973] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:48,042] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:48,079] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:48,182] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:48,349] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:48,390] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:48,392] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:48,601] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:48,651] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:48,656] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:48,810] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:48,944] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:48,952] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:49,020] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:49,153] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:49,229] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:49,252] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:49,363] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:49,462] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:49,487] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:49,571] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:49,671] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:49,696] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:49,781] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:49,880] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:49,904] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:50,089] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:50,099] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:50,203] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:50,298] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:50,402] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:50,507] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:50,529] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:50,712] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:50,716] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:50,831] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:50,924] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:51,023] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:51,133] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:51,148] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:51,232] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:51,342] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:51,452] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:51,544] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:51,551] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:51,767] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:51,846] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:51,857] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:51,976] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:52,056] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:52,151] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:52,264] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:52,274] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:52,361] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:52,475] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:52,570] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:52,583] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:52,684] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:52,779] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:52,792] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:52,893] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:52,988] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:53,002] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:53,102] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:53,213] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:53,285] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:53,311] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:53,422] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:53,520] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:53,606] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:53,631] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:53,821] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:53,840] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:53,912] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:54,052] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:54,136] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:54,212] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:54,263] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.
# [2022-02-28 11:15:54
- obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - No data available for request.

# %%
'''

Set station and channel info

'''

path = "/media/Data/Data/"
networks = ["YT"]
stats = [["MCRG","MA01","MA02","MA08"]]
chans = ["HH*"]

# %%
'''

Remove instrumental response

'''

# set times of interest
time_win_dict = {}
time_win_dict[0] = {'start':datetime.datetime(2011,10,2),'end':datetime.datetime(2011,10,10)}
time_win_dict[1] = {'start':datetime.datetime(2012,5,8),'end':datetime.datetime(2012,5,10)}
time_win_dict[2] = {'start':datetime.datetime(2015,7,8),'end':datetime.datetime(2015,7,20)}
time_win_dict[3] = {'start':datetime.datetime(2017,9,13),'end':datetime.datetime(2017,9,25)}
time_win_dict[4] = {'start':datetime.datetime(2018,9,21),'end':datetime.datetime(2018,10,25)}

#set frequency band for response removal
prefilt = [[0.0005,0.001,45,50]]

for i in range(len(time_win_dict)):
    for n in range(len(networks)):
        duration = time_win_dict[i]['end']-time_win_dict[i]['start']
        files = []
        for day in range(0,duration.days):
            date = time_win_dict[i]['start']+datetime.timedelta(days=day)
            files.extend([path + networks[n] + "/MSEED/raw/" + stat + "/*" + chans[n] + "__" + str(date.year) + date.strftime('%m') + date.strftime('%d') + "T000000Z__" + "*" for stat in stats[n]])

        #loop through all raw files
        for f in files:

            #start timer
            t = time.time()

            #read in one data file
            try:
                st = obspy.read(f)
            except:
                print("No data for " + str(f))
                continue
                
            #grab a couple useful variables from file metadata
            station = st[0].stats.station
            channel = st[0].stats.channel
            start_date = str(st[0].stats.starttime).split("T")[0]

            #specify output filename format
            out_path = "data/MSEED/"+networks[n]+"/"
            out_file = out_path + st[0].stats.station + "_" + start_date + "_" + str(prefilt[n][1]) + "-" + str(prefilt[n][2]) + "Hz.MSEED"
            if not os.path.exists(out_path):
                os.makedirs(out_path)

            #preprocess file
            st.detrend("demean")
            st.detrend("linear")
            st.taper(max_percentage=0.00025, max_length=20.)

            #read correct stationXML file
            XML_path = glob.glob(path + networks[n] + "/XML/*" + station + "*.xml")[0]
            inv = obspy.read_inventory(XML_path)

            #remove instrument response
            st.remove_response(inventory=inv,pre_filt=prefilt[n],output="VEL")

            #write new file
            st.write(out_file,format='MSEED')

            #end timer
            run_time = time.time() - t

            #give some output to check progress
            print("Response removed from " + f + " in " + str(run_time) + " seconds.")
# Out:
# /opt/anaconda3/envs/obspy/lib/python3.7/site-packages/obspy/io/mseed/core.py:790: UserWarning: The encoding specified in trace.stats.mseed.encoding does not match the dtype of the data.
# A suitable encoding will be chosen.
#   warnings.warn(msg, UserWarning)
# Response removed from /media/Data/Data/YT/MSEED/raw/DNTW/*BH*__20120508T000000Z__* in 16.464916229248047 seconds.
# /opt/anaconda3/envs/obspy/lib/python3.7/site-packages/obspy/io/mseed/core.py:790: UserWarning: The encoding specified in trace.stats.mseed.encoding does not match the dtype of the data.
# A suitable encoding will be chosen.
#   warnings.warn(msg, UserWarning)
# Response removed from /media/Data/Data/YT/MSEED/raw/UPTW/*BH*__20120508T000000Z__* in 18.966939449310303 seconds.
# /opt/anaconda3/envs/obspy/lib/python3.7/site-packages/obspy/io/mseed/core.py:790: UserWarning: The encoding specified in trace.stats.mseed.encoding does not match the dtype of the data.
# A suitable encoding will be chosen.
#   warnings.warn(msg, UserWarning)
# Response removed from /media/Data/Data/YT/MSEED/raw/THUR/*BH*__20120508T000000Z__* in 19.581763744354248 seconds.
# /opt/anaconda3/envs/obspy/lib/python3.7/site-packages/obspy/io/mseed/core.py:790: UserWarning: The encoding specified in trace.stats.mseed.encoding does not match the dtype of the data.
# A suitable encoding will be chosen.
#   warnings.warn(msg, UserWarning)
# Response removed from /media/Data/Data/YT/MSEED/raw/BEAR/*BH*__20120508T000000Z__* in 18.13138437271118 seconds.
# /opt/anaconda3/envs/obspy/lib/python3.7/site-packages/obspy/io/mseed/core.py:790: UserWarning: The encoding specified in trace.stats.mseed.encoding does not match the dtype of the data.
# A suitable encoding will be chosen.
#   warnings.warn(msg, UserWarning)
# Response removed from /media/Data/Data/YT/MSEED/raw/DNTW/*BH*__20120509T000000Z__* in 17.266552925109863 seconds.
# /opt/anaconda3/envs/obspy/lib/python3.7/site-packages/obspy/io/mseed/core.py:790: UserWarning: The encoding specified in trace.stats.mseed.encoding does not match the dtype of the data.
# A suitable encoding will be chosen.
#   warnings.warn(msg, UserWarning)
# Response removed from /media/Data/Data/YT/MSEED/raw/UPTW/*BH*__20120509T000000Z__* in 18.48106288909912 seconds.
# /opt/anaconda3/envs/obspy/lib/python3.7/site-packages/obspy/io/mseed/core.py:790: UserWarning: The encoding specified in trace.stats.mseed.encoding does not match the dtype of the data.
# A suitable encoding will be chosen.
#   warnings.warn(msg, UserWarning)
# Response removed from /media/Data/Data/YT/MSEED/raw/THUR/*BH*__20120509T000000Z__* in 18.409836530685425 seconds.
# Response removed from /media/Data/Data/YT/MSEED/raw/BEAR/*BH*__20120509T000000Z__* in 18.583863735198975 seconds.
# /opt/anaconda3/envs/obspy/lib/python3.7/site-packages/obspy/io/mseed/core.py:790: UserWarning: The encoding specified in trace.stats.mseed.encoding does not match the dtype of the data.
# A suitable encoding will be chosen.
#   warnings.warn(msg, UserWarning)

# %%
'''

Check which stations are available for times where imagery suggests rift activity

'''

# set times of interest
time_win_dict = {}
time_win_dict[0] = {'start':datetime.datetime(2011,10,2),'end':datetime.datetime(2011,10,10)}
time_win_dict[1] = {'start':datetime.datetime(2015,7,8),'end':datetime.datetime(2015,7,20)}
time_win_dict[2] = {'start':datetime.datetime(2017,9,13),'end':datetime.datetime(2017,9,25)}
time_win_dict[3] = {'start':datetime.datetime(2018,9,21),'end':datetime.datetime(2018,10,25)}

# plot station availability during times of interest
fig = plt.figure(figsize=(15,5))
position = 0
for n in range(len(networks)):
    for s in range(len(stats[n])):
        files = glob.glob(path + networks[n] + "/MSEED/raw/" + stats[n][s] + "/*" + chans[n] + "*")
        dates = [datetime.datetime.strptime(f.split("__")[1],"%Y%m%dT000000Z") for f in files]
        plt.plot(dates,np.ones(len(dates))+position,label=stats[n][s])
        position += 1
plt.legend()
plt.title("Station availability")
plt.show()

rifts = ["2011 rift","2015 rift","2017 rift", "2018 rift"]
fig,ax = plt.subplots(len(time_win_dict),figsize=(10,12))
position = 0
for i in range(len(time_win_dict)):
    for n in range(len(networks[n])):
        for s in range(len(stats[n])):
            files = glob.glob(path + networks[n] + "/MSEED/raw/" + stats[n][s] + "/*" + chans[n] + "*")
            dates = np.array([datetime.datetime.strptime(f.split("__")[1],"%Y%m%dT000000Z") for f in files])
            time_ind = np.logical_and([dates>time_win_dict[i]['start']],[dates<time_win_dict[i]['end']])[0]
            ax[i].plot(dates[time_ind],np.ones(len(dates[time_ind]))+position,label=stats[n][s])
            position+=1
    ax[i].set_title(rifts[i])
    ax[i].legend()
plt.tight_layout()

# %%
'''

Plot all available data for each time period of interest

'''

# set times of interest
time_win_dict = {}
time_win_dict[0] = {'start':datetime.datetime(2011,10,2),'end':datetime.datetime(2011,10,10)}
time_win_dict[1] = {'start':datetime.datetime(2015,7,8),'end':datetime.datetime(2015,7,20)}
time_win_dict[2] = {'start':datetime.datetime(2017,9,13),'end':datetime.datetime(2017,9,25)}
time_win_dict[3] = {'start':datetime.datetime(2018,9,21),'end':datetime.datetime(2018,10,25)}

# choose channel and frequency band
chan = "*Z"
low_cut = 0.1
high_cut = 1

# make labels for plots
rifts = ["2011 rift","2015 rift","2017 rift", "2018 rift"]

for i in range(len(time_win_dict)):
    data_dict = {}
    # read all data available on the current day
    duration = time_win_dict[i]['end']-time_win_dict[i]['start']
    for day in range(0,duration.days):

        # get date from time window dictionary
        date = time_win_dict[i]['start']+datetime.timedelta(days=day)

        # read and preprocess data
        st = obspy.read("data/MSEED/*/*" + str(date.year) + "-" + date.strftime('%m') + "-" + date.strftime('%d') + "*")
        st.detrend("demean")
        st.detrend("linear")
        st.taper(max_percentage=0.00025, max_length=20.)
        st.filter("bandpass",freqmin=low_cut,freqmax=high_cut)
        st.resample(high_cut*2)
        
        for tr in st.select(channel=chan):
            data_key = tr.stats.station+tr.stats.channel+"_data"
            time_key = tr.stats.station+tr.stats.channel+"_time"
            if data_key in data_dict.keys():
                data_dict[data_key] = np.append(data_dict[data_key],tr.data)
                data_dict[time_key] = np.append(data_dict[time_key],tr.times(type="matplotlib"))
            else:
                data_dict[data_key] = tr.data
                data_dict[time_key] = tr.times(type="matplotlib")

    fig,ax = plt.subplots(len(data_dict)//2,1,figsize=(20,10))
    data_keys = [k for k in data_dict.keys() if "data" in k]
    time_keys = [k for k in data_dict.keys() if "time" in k]
    nrows = len(data_keys)-1
    for k in range(len(data_keys)):
        ax[k].plot(data_dict[time_keys[k]],data_dict[data_keys[k]],color='k')
        ax[k].get_xaxis().set_ticklabels([])
        ax[nrows].get_shared_x_axes().join(ax[nrows],ax[k])
        ax[k].set_ylabel("Velocity (m/s)")
        ax[k].set_title(data_keys[k].split("_")[0])
        if k == nrows:
            ax[k].xaxis.set_major_formatter(mdates.DateFormatter('%m/%d\n%H:%M'))
    plt.suptitle("Data surrounding " + rifts[i] + " extension (" + str(low_cut)+"-" + str(high_cut)+" Hz)")
    plt.tight_layout()
    plt.savefig("outputs/timeseries/" + time_win_dict[i]['start'].strftime("%Y-%m-%d") + "_" + time_win_dict[i]['end'].strftime("%Y-%m-%d") + "_" + chan.split("*")[1] + "_" + str(low_cut)+ "-" + str(high_cut)+ "Hz" + ".png")
